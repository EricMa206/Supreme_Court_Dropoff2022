# %%
import numpy as np
import pandas as pd
import re
import requests
from bs4 import BeautifulSoup

# %%
try:
    headers = {"User-Agent": "Mozilla/5.0 (Macintosh; Intel Mac OS X 10_14_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/96.0.4664.45 Safari/537.36"}
    r = requests.get('https://www.golubcapital.com/our-firm/#leadership', headers = headers)
except requests.exceptions.RequestException as e: 
    raise SystemExit(e)

# %%
BeautifulSoup(r.content, 'html.parser').prettify
# Out:
# <?xml version="1.0" encoding="utf-8"?>
# <!DOCTYPE HTML>
# <html>
# <head>
# <title>Our Firm | Golub Capital</title>
# <meta charset="UTF-8">
# <meta content="width=device-width, user-scalable=1.0,initial-scale=1.0,minimum-scale=1.0,maximum-scale=1.0" name="viewport">
# <meta content="yes" name="apple-mobile-web-app-capable">
# <meta content="telephone=no" name="format-detection">
# <!-- favicons -->
# <link href="https://golubcapital.com/wp-content/themes/GolubTemplate/images/favicons/favicon.ico" rel="shortcut icon"/>
# <!-- OneTrust Cookies Consent Notice start -->
# <script src="https://cdn.cookielaw.org/consent/79224a50-8ac2-4469-aaae-5406371ecc49/OtAutoBlock.js" type="text/javascript"/>
# <script charset="UTF-8" data-domain-script="79224a50-8ac2-4469-aaae-5406371ecc49" src="https://cdn.cookielaw.org/scripttemplates/otSDKStub.js" type="text/javascript"/>
# <script type="text/javascript">
# 				function OptanonWrapper() { }
# 				</script>
# ...

# %%
HTMLDoc = BeautifulSoup(r.content, 'html.parser')

# %%
bios = []
for bio in HTMLDoc.find_all('div', class_ = 'gc_professionals_single_card'):
    bios.append({'Name': bio.h3.text, 
                'Title': bio.span.text})
bios
# Out:
# [{'Name': 'Lawrence E. Golub', 'Title': 'Chief Executive Officer'},
#  {'Name': 'David B. Golub', 'Title': 'President'},
#  {'Name': 'Andrew H. Steuerman',
#   'Title': 'Vice Chair of Direct Lending and Late Stage Lending'},
#  {'Name': 'Gregory W. Cashman', 'Title': 'Head of Direct Lending '},
#  {'Name': 'Scott Morrison', 'Title': 'Head of Broadly Syndicated Loans'},
#  {'Name': 'Craig Benton',
#   'Title': 'Senior Managing Director, Head of Structured Products'},
#  {'Name': 'Alissa Grad',
#   'Title': 'Senior Managing Director, Co-Head of the Investor Partners Group'},
#  {'Name': 'Gregory A. Robbins',
#   'Title': 'Senior Managing Director, Co-Head of the Investor Partners Group'},
#  {'Name': 'Michele D. Joyeux', 'Title': 'Managing Director'},
#  {'Name': 'Frank P. Straub',
#   'Title': 'Chief Financial Officer and Chief Administrative Officer'},
#  {'Name': 'Pierre-Olivier Lamoureux',
#   'Title': 'Chief Financial Officer, GC Advisors LLC'},
#  {'Name': 'Joshua M. Levinson',
# ...

# %%
pd.DataFrame(titles)
# Out:
#                         Name  \
# 0          Lawrence E. Golub
# 1             David B. Golub
# 2        Andrew H. Steuerman
# 3         Gregory W. Cashman
# 4             Scott Morrison
# 5               Craig Benton
# 6                Alissa Grad
# 7         Gregory A. Robbins
# 8          Michele D. Joyeux
# 9            Frank P. Straub
# 10  Pierre-Olivier Lamoureux
# 11        Joshua M. Levinson
# 12        Susan M. Czarnecki
# 13        Timothy G. Kleiman
#
#                                                 Title
# 0                             Chief Executive Officer
# 1                                           President
# 2   Vice Chair of Direct Lending and Late Stage Le...
# 3                             Head of Direct Lending
# 4                    Head of Broadly Syndicated Loans
# 5   Senior Managing Director, Head of Structured P...
# 6   Senior Managing Director, Co-Head of the Inves...
# 7   Senior Managing Director, Co-Head of the Inves...
# ...
