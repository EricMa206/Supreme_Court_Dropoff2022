# %%
# Libraries
import pandas as pd
import numpy as np
import geopandas

# %%
ls
# Out:
# NC_Crosswalk.csv            SBE_PRECINCTS_20141016.zip
# NC_Crosswalk.ipynb          SBE_PRECINCTS_20161004/
# NC_Crosswalk.py             SBE_PRECINCTS_20161004.zip
# NC_returns_3_16.csv         layout_results_sort.txt
# SBE_PRECINCTS_20141016/

# %%
# Load in shapefiles
precincts2016 = geopandas.read_file('SBE_PRECINCTS_20161004/PRECINCTS.shp')

# %%
precincts2014 = geopandas.read_file('SBE_PRECINCTS_20141016/PRECINCTS.shp')

# %%
# Create a unique id for each precinct in 2016 &2014
precincts2016['Prec_Uid'] = precincts2016['COUNTY_NAM'] + '|' + precincts2016['PREC_ID']
precincts2014['Prec_Uid'] = precincts2014['COUNTY_NAM'] + '|' + precincts2014['PREC_ID']

# %%
precincts2016.info()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
# RangeIndex: 2704 entries, 0 to 2703
# Data columns (total 7 columns):
# PREC_ID       2704 non-null object
# ENR_DESC      2700 non-null object
# COUNTY_NAM    2704 non-null object
# OF_PREC_ID    12 non-null object
# COUNTY_ID     2704 non-null int64
# geometry      2704 non-null geometry
# Prec_Uid      2704 non-null object
# dtypes: geometry(1), int64(1), object(5)
# memory usage: 148.0+ KB

# %%
# Preparing for matches for comparison
join2016 = precincts2016.astype({'geometry': str})
join2014 = precincts2014.astype({'geometry': str})

# %%
fullmatch = join2016.merge(join2014, how='outer', on=['Prec_Uid', 'geometry'], suffixes=['16','14'])

# %%
# Finding perfect matches (2609)
perfectmatch = fullmatch[['Prec_Uid', 'geometry', 'COUNTY_NAM16', 'COUNTY_NAM14']].dropna()
perfect = perfectmatch['Prec_Uid'].tolist()

# %%
nonmatch16 = fullmatch[['Prec_Uid', 'geometry', 'ENR_DESC16']][fullmatch['COUNTY_NAM14'].isna()]
nonmatch14 = fullmatch[['Prec_Uid', 'geometry', 'ENR_DESC14']][fullmatch['COUNTY_NAM16'].isna()]

# %%
# Finding perfect geometry matches (62)
geommatch = nonmatch16.merge(nonmatch14, 'inner', on='geometry', suffixes=['16','14'])
geom = geommatch['Prec_Uid16'].tolist()

# %%
# Finded Precincts with the same id (4)
name = nonmatch16.merge(nonmatch14, 'inner', on='Prec_Uid', suffixes=['16','14'])['Prec_Uid'].tolist()

# %%
# Geom does not match (2016:33, 2014:116)
mod16 = precincts2016[~precincts2016['Prec_Uid'].isin(perfect+geom)]
mod14 = precincts2014[~precincts2014['Prec_Uid'].isin(perfect+geom)]
mod16
# Out:
#      PREC_ID                           ENR_DESC   COUNTY_NAM OF_PREC_ID  \
# 41       06A                 06A_PRATHERS CREEK    ALLEGHANY       None
# 43       03A                      03A_GAP CIVIL    ALLEGHANY       None
# 61      G1G2               G1G2- GWALTNEY #1 #2    ALEXANDER       None
# 62      LRSL  LRSL- LITTLE RIVER AND SUGAR LOAF    ALEXANDER       None
# 64      S1S2                S1S2- SHARPES #1 #2    ALEXANDER       None
# 65    T1T4T5      T1T4T5- TAYLORSVILLE #1 #4 #5    ALEXANDER       None
# 89      T2T3           T2T3- TAYLORSVILLE #2 #3    ALEXANDER       None
# 395      H12                                H12  NEW HANOVER       None
# 431     FP08                               FP08  NEW HANOVER       None
# 611       PH                   PH_PROSPECT HILL      CASWELL       None
# 674    SOUTH               SOUTH_ELIZABETH CITY   PASQUOTANK       None
# 675     WEST                WEST_ELIZABETH CITY   PASQUOTANK       None
# 676     EAST                EAST_ELIZABETH CITY   PASQUOTANK       None
# 795     P19A          P19A_ROCKY MOUNT WINSTEAD         NASH       None
# 801     P21A          P21A_ROCKY MOUNT DOWNTOWN         NASH       None
# 893     RCTL               RCTL_Roxboro Central       PERSON       None
# 894     SWST                    SWST_South West       PERSON       None
# 1183    PNTH                PNTH_Piedmont North       PERSON       None
# 1281    PR33                    PR33_HUDSON #33     CALDWELL       None
# 1282    PR13                  PR13_LITTLE RIVER     CALDWELL       None
# 1283    PR34                  PR34_LOVELADY-TWO     CALDWELL       None
# 1285    PR35                  PR35_LOVELADY-ONE     CALDWELL       None
# 1770     RRC           RRC_ROANOKE RAPIDS CIVIC      HALIFAX       None
# 1772  WEL1-2                         WELDON 1-2      HALIFAX       None
# 2181   NORTH               NORTH_ELIZABETH CITY   PASQUOTANK       None
# 2382    P16A        P16A_ROCKY MOUNT BATTLEBORO         NASH       None
# 2641   20-15                              20-15         WAKE       None
# 2642   20-14                              20-14         WAKE       None
# 2644   05-07                              05-07         WAKE       None
# 2654      75                   75_EAST WILLIAMS      CHATHAM       None
# 2701   20-17                              20-17         WAKE       None
# 2702   20-16                              20-16         WAKE       None
# 2703     H13                                H13  NEW HANOVER       None
#
#       COUNTY_ID                                           geometry  \
# 41            3  POLYGON ((1319631.190552548 1036268.793138728,...
# 43            3  POLYGON ((1367522.2118963 1033295.261684224, 1...
# 61            2  POLYGON ((1401206.240656719 838760.7626306415,...
# 62            2  POLYGON ((1352488.494916558 839019.7811414748,...
# 64            2  POLYGON ((1378629.670324385 823969.7092075646,...
# 65            2  POLYGON ((1351829.208505467 807612.7130502313,...
# 89            2  POLYGON ((1356158.102078632 812742.7697192281,...
# 395          65  POLYGON ((2380123.480652973 201267.0304028094,...
# 431          65  POLYGON ((2359305.6161208 116489.2052081376, 2...
# 611          17  POLYGON ((1935209.22415781 965528.726941973, 1...
# 674          70  POLYGON ((2820114.734198883 936344.1514529735,...
# 675          70  POLYGON ((2814052.101967216 937985.9956102222,...
# 676          70  POLYGON ((2817802.939937964 939682.6175450534,...
# 795          64  POLYGON ((2340925.775583968 811735.2632040679,...
# 801          64  POLYGON ((2360220.208451718 811400.5614456385,...
# 893          73  POLYGON ((2003667.799838796 963576.2347839773,...
# 894          73  POLYGON ((1966465.139336139 953947.3232675642,...
# 1183         73  POLYGON ((2006983.856526881 980814.1012268066,...
# 1281         14  POLYGON ((1271946.981131136 784330.0529227257,...
# 1282         14  POLYGON ((1311298.501181215 825719.593503058, ...
# 1283         14  POLYGON ((1301963.976871297 769978.6173868179,...
# 1285         14  POLYGON ((1300134.114061221 769642.6488986462,...
# 1770         42  POLYGON ((2396352.908495888 989193.8521838039,...
# 1772         42  POLYGON ((2405545.244769976 983102.5093796402,...
# 2181         70  POLYGON ((2815192.622652054 952242.9129624814,...
# 2382         64  POLYGON ((2367872.867030889 849920.3298783898,...
# 2641         92  POLYGON ((2035181.853608474 762124.8558633924,...
# 2642         92  POLYGON ((2032184.852056548 747063.365317151, ...
# 2644         92  POLYGON ((2038429.06791456 770713.5099458992, ...
# 2654         19  POLYGON ((2025761.193644047 758285.5807335675,...
# 2701         92  POLYGON ((2037766.392074555 754359.9419313073,...
# 2702         92  POLYGON ((2025761.193644047 758285.5807335675,...
# 2703         65  POLYGON ((2380123.480652973 201267.0304028094,...
#
#               Prec_Uid
# 41       ALLEGHANY|06A
# 43       ALLEGHANY|03A
# 61      ALEXANDER|G1G2
# 62      ALEXANDER|LRSL
# 64      ALEXANDER|S1S2
# 65    ALEXANDER|T1T4T5
# 89      ALEXANDER|T2T3
# 395    NEW HANOVER|H12
# 431   NEW HANOVER|FP08
# 611         CASWELL|PH
# 674   PASQUOTANK|SOUTH
# 675    PASQUOTANK|WEST
# 676    PASQUOTANK|EAST
# 795          NASH|P19A
# 801          NASH|P21A
# 893        PERSON|RCTL
# 894        PERSON|SWST
# 1183       PERSON|PNTH
# 1281     CALDWELL|PR33
# 1282     CALDWELL|PR13
# 1283     CALDWELL|PR34
# 1285     CALDWELL|PR35
# 1770       HALIFAX|RRC
# 1772    HALIFAX|WEL1-2
# 2181  PASQUOTANK|NORTH
# 2382         NASH|P16A
# 2641        WAKE|20-15
# 2642        WAKE|20-14
# 2644        WAKE|05-07
# 2654        CHATHAM|75
# 2701        WAKE|20-17
# 2702        WAKE|20-16
# 2703   NEW HANOVER|H13

# %%
# Only checking against 2014 precincts that were not captured in Perfect or Geom matches
mod14_dict = mod14[['Prec_Uid', 'geometry']].to_dict('records')

# %%
def check_merge(row):
    precincts = []
    for p in mod14_dict:
        if row['geometry'].contains(p['geometry']):
            precincts.append(p['Prec_Uid'])
    if len(precincts)>0:
        return precincts
    else:
        return np.nan

# %%
def check_split(row):
    for p in mod14_dict:
        if row['geometry'].within(p['geometry']):
            return p['Prec_Uid']
    return np.nan

# %%
mod16['Merge'] = mod16.apply(lambda i: check_merge(i), axis=1)
mod16['Split'] = mod16.apply(lambda i: check_split(i), axis=1)
# Out:
# /Users/ericma/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/ericma/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
# Set index to make lookups easier
mod16.set_index('Prec_Uid',inplace=True)

# %%
merged = mod16['Merge'][mod16['Merge'].notna()].to_dict()
split = mod16['Split'][mod16['Split'].notna()].to_dict()
merged
# Out:
# {'ALLEGHANY|06A': ['ALLEGHANY|02', 'ALLEGHANY|06', 'ALLEGHANY|05'],
#  'ALLEGHANY|03A': ['ALLEGHANY|07', 'ALLEGHANY|03'],
#  'ALEXANDER|G1G2': ['ALEXANDER|G1', 'ALEXANDER|G2'],
#  'ALEXANDER|LRSL': ['ALEXANDER|L', 'ALEXANDER|SL'],
#  'ALEXANDER|S1S2': ['ALEXANDER|S1', 'ALEXANDER|S2'],
#  'ALEXANDER|T1T4T5': ['ALEXANDER|T1', 'ALEXANDER|T4', 'ALEXANDER|T5'],
#  'ALEXANDER|T2T3': ['ALEXANDER|T2', 'ALEXANDER|T3'],
#  'NEW HANOVER|FP08': ['NEW_HANOVER|FP02', 'NEW_HANOVER|FP05'],
#  'CASWELL|PH': ['CASWELL|HIGH', 'CASWELL|PROS'],
#  'PASQUOTANK|SOUTH': ['PASQUOTANK|4-A', 'PASQUOTANK|4-B'],
#  'PASQUOTANK|WEST': ['PASQUOTANK|3-B', 'PASQUOTANK|3-A'],
#  'PASQUOTANK|EAST': ['PASQUOTANK|1-A', 'PASQUOTANK|1-B'],
#  'NASH|P19A': ['NASH|0039', 'NASH|0037'],
#  'NASH|P21A': ['NASH|0031', 'NASH|0032'],
#  'PERSON|RCTL': ['PERSON|RX1A', 'PERSON|ROX1'],
#  'PERSON|SWST': ['PERSON|HUML', 'PERSON|BFRK'],
#  'PERSON|PNTH': ['PERSON|ROX2', 'PERSON|ROX3'],
#  'CALDWELL|PR33': ['CALDWELL|PR06', 'CALDWELL|PR05'],
#  'HALIFAX|RRC': ['HALIFAX|RR 6', 'HALIFAX|RR 8'],
#  'HALIFAX|WEL1-2': ['HALIFAX|WEL 1', 'HALIFAX|WEL 2'],
#  'PASQUOTANK|NORTH': ['PASQUOTANK|2-B', 'PASQUOTANK|2-A'],
#  'NASH|P16A': ['NASH|0042', 'NASH|0002'],
#  'CHATHAM|75': ['CHATHAM|75']}

# %%
# Load in returns
returns = pd.read_csv('NC_returns_3_16.csv')

# %%
# Create a unique id for each precinct
returns['PrecReturns_id'] = returns['County'] + '|' + returns['Precinct']
returns
# Out:
#           County Election Date     Precinct  Contest Group ID Contest Type  \
# 0      ALEXANDER    03/15/2016            E              1001            S
# 1      ALEXANDER    03/15/2016         S1S2              1001            S
# 2      ALEXANDER    03/15/2016         LRSL              1001            S
# 3      ALEXANDER    03/15/2016            W              1001            S
# 4      ALEXANDER    03/15/2016         T2T3              1001            S
# 5      ALEXANDER    03/15/2016           B2              1001            S
# 6      ALEXANDER    03/15/2016         G1G2              1001            S
# 7      ALEXANDER    03/15/2016           B1              1001            S
# 8      ALEXANDER    03/15/2016       T1T4T5              1001            S
# 9      ALEXANDER    03/15/2016            M              1001            S
# 10     ALEXANDER    03/15/2016           B1              1001            S
# 11     ALEXANDER    03/15/2016            E              1001            S
# 12     ALEXANDER    03/15/2016       T1T4T5              1001            S
# 13     ALEXANDER    03/15/2016         S1S2              1001            S
# 14     ALEXANDER    03/15/2016            W              1001            S
# 15     ALEXANDER    03/15/2016         LRSL              1001            S
# 16     ALEXANDER    03/15/2016           B2              1001            S
# 17     ALEXANDER    03/15/2016            M              1001            S
# 18     ALEXANDER    03/15/2016         T2T3              1001            S
# 19     ALEXANDER    03/15/2016         G1G2              1001            S
# 20     ALEXANDER    03/15/2016           B1              1001            S
# 21     ALEXANDER    03/15/2016         LRSL              1001            S
# 22     ALEXANDER    03/15/2016           B2              1001            S
# 23     ALEXANDER    03/15/2016            M              1001            S
# 24     ALEXANDER    03/15/2016         S1S2              1001            S
# 25     ALEXANDER    03/15/2016            W              1001            S
# 26     ALEXANDER    03/15/2016         G1G2              1001            S
# 27     ALEXANDER    03/15/2016         T2T3              1001            S
# 28     ALEXANDER    03/15/2016            E              1001            S
# 29     ALEXANDER    03/15/2016       T1T4T5              1001            S
# ...          ...           ...          ...               ...          ...
# 67058     YADKIN    03/15/2016         NLIB              1058            S
# 67059     YADKIN    03/15/2016  PROVISIONAL              1058            S
# 67060     YADKIN    03/15/2016         NFAL              1058            S
# 67061     YADKIN    03/15/2016         FBSH              1058            S
# 67062     YADKIN    03/15/2016         FBSH              1058            S
# 67063     YADKIN    03/15/2016         SFAL              1058            S
# 67064     YADKIN    03/15/2016         NBCK              1058            S
# 67065     YADKIN    03/15/2016         NKNB              1058            S
# 67066     YADKIN    03/15/2016         SBCK              1058            S
# 67067     YADKIN    03/15/2016         SKNB              1058            S
# 67068     YADKIN    03/15/2016         DCRK              1058            S
# 67069     YADKIN    03/15/2016         EBND              1058            S
# 67070     YADKIN    03/15/2016         NFAL              1058            S
# 67071     YADKIN    03/15/2016     ONE STOP              1058            S
# 67072     YADKIN    03/15/2016  PROVISIONAL              1058            S
# 67073     YADKIN    03/15/2016         NLIB              1058            S
# 67074     YADKIN    03/15/2016     ABSENTEE              1058            S
# 67075     YADKIN    03/15/2016         SLIB              1058            S
# 67076     YADKIN    03/15/2016         BNVL              1058            S
# 67077     YADKIN    03/15/2016         NBCK              1061            S
# 67078     YADKIN    03/15/2016         SBCK              1061            S
# 67079     YADKIN    03/15/2016         FBSH              1061            S
# 67080     YADKIN    03/15/2016         SLIB              1061            S
# 67081     YADKIN    03/15/2016         NKNB              1061            S
# 67082     YADKIN    03/15/2016         EBND              1061            S
# 67083     YADKIN    03/15/2016         SFAL              1061            S
# 67084     YADKIN    03/15/2016         NFAL              1061            S
# 67085     YADKIN    03/15/2016     ABSENTEE              1061            S
# 67086     YADKIN    03/15/2016     ONE STOP              1061            S
# 67087     YADKIN    03/15/2016         NLIB              1061            S
#
#                                         Contest Name              Choice  \
# 0                                 US PRESIDENT (DEM)      Bernie Sanders
# 1                                 US PRESIDENT (DEM)      Bernie Sanders
# 2                                 US PRESIDENT (DEM)      Bernie Sanders
# 3                                 US PRESIDENT (DEM)      Bernie Sanders
# 4                                 US PRESIDENT (DEM)      Bernie Sanders
# 5                                 US PRESIDENT (DEM)      Bernie Sanders
# 6                                 US PRESIDENT (DEM)      Bernie Sanders
# 7                                 US PRESIDENT (DEM)      Bernie Sanders
# 8                                 US PRESIDENT (DEM)      Bernie Sanders
# 9                                 US PRESIDENT (DEM)      Bernie Sanders
# 10                                US PRESIDENT (DEM)     Hillary Clinton
# 11                                US PRESIDENT (DEM)     Hillary Clinton
# 12                                US PRESIDENT (DEM)     Hillary Clinton
# 13                                US PRESIDENT (DEM)     Hillary Clinton
# 14                                US PRESIDENT (DEM)     Hillary Clinton
# 15                                US PRESIDENT (DEM)     Hillary Clinton
# 16                                US PRESIDENT (DEM)     Hillary Clinton
# 17                                US PRESIDENT (DEM)     Hillary Clinton
# 18                                US PRESIDENT (DEM)     Hillary Clinton
# 19                                US PRESIDENT (DEM)     Hillary Clinton
# 20                                US PRESIDENT (DEM)  Martin J. O'Malley
# 21                                US PRESIDENT (DEM)  Martin J. O'Malley
# 22                                US PRESIDENT (DEM)  Martin J. O'Malley
# 23                                US PRESIDENT (DEM)  Martin J. O'Malley
# 24                                US PRESIDENT (DEM)  Martin J. O'Malley
# 25                                US PRESIDENT (DEM)  Martin J. O'Malley
# 26                                US PRESIDENT (DEM)  Martin J. O'Malley
# 27                                US PRESIDENT (DEM)  Martin J. O'Malley
# 28                                US PRESIDENT (DEM)  Martin J. O'Malley
# 29                                US PRESIDENT (DEM)  Martin J. O'Malley
# ...                                              ...                 ...
# 67058                             NC TREASURER (DEM)        Dan Blue III
# 67059                             NC TREASURER (DEM)        Dan Blue III
# 67060                             NC TREASURER (DEM)        Dan Blue III
# 67061                             NC TREASURER (DEM)        Dan Blue III
# 67062                             NC TREASURER (DEM)           Ron Elmer
# 67063                             NC TREASURER (DEM)           Ron Elmer
# 67064                             NC TREASURER (DEM)           Ron Elmer
# 67065                             NC TREASURER (DEM)           Ron Elmer
# 67066                             NC TREASURER (DEM)           Ron Elmer
# 67067                             NC TREASURER (DEM)           Ron Elmer
# 67068                             NC TREASURER (DEM)           Ron Elmer
# 67069                             NC TREASURER (DEM)           Ron Elmer
# 67070                             NC TREASURER (DEM)           Ron Elmer
# 67071                             NC TREASURER (DEM)           Ron Elmer
# 67072                             NC TREASURER (DEM)           Ron Elmer
# 67073                             NC TREASURER (DEM)           Ron Elmer
# 67074                             NC TREASURER (DEM)           Ron Elmer
# 67075                             NC TREASURER (DEM)           Ron Elmer
# 67076                             NC TREASURER (DEM)           Ron Elmer
# 67077  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67078  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67079  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67080  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67081  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67082  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67083  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67084  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67085  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67086  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
# 67087  NC SUPERINTENDENT OF PUBLIC INSTRUCTION (DEM)     Henry J. Pankey
#
#       Choice Party  Vote For  Election Day  One Stop  Absentee by Mail  \
# 0              DEM         1            85        39                 1
# 1              DEM         1            92        30                 0
# 2              DEM         1            57        13                 0
# 3              DEM         1            46        28                 0
# 4              DEM         1            77        42                 3
# 5              DEM         1           117        37                 3
# 6              DEM         1            90        11                 0
# 7              DEM         1            89        27                 2
# 8              DEM         1           104        69                 3
# 9              DEM         1            49        10                 0
# 10             DEM         1            48        25                 2
# 11             DEM         1            56        49                 1
# 12             DEM         1            89       100                 4
# 13             DEM         1            81        59                 2
# 14             DEM         1            37        25                 0
# 15             DEM         1            40        31                 0
# 16             DEM         1            94        41                 4
# 17             DEM         1            69        18                 0
# 18             DEM         1            89        99                 4
# 19             DEM         1            59        23                 0
# 20             DEM         1             2         0                 0
# 21             DEM         1             4         0                 1
# 22             DEM         1             8         5                 0
# 23             DEM         1             3         1                 0
# 24             DEM         1             4         2                 2
# 25             DEM         1             1         2                 0
# 26             DEM         1             3         1                 0
# 27             DEM         1             2         4                 0
# 28             DEM         1             4         3                 0
# 29             DEM         1             4         3                 0
# ...            ...       ...           ...       ...               ...
# 67058          DEM         1            83         0                 0
# 67059          DEM         1             0         0                 0
# 67060          DEM         1            22         0                 0
# 67061          DEM         1            64         0                 0
# 67062          DEM         1            58         0                 0
# 67063          DEM         1            34         0                 0
# 67064          DEM         1            32         0                 0
# 67065          DEM         1           109         0                 0
# 67066          DEM         1            33         0                 0
# 67067          DEM         1            11         0                 0
# 67068          DEM         1            45         0                 0
# 67069          DEM         1            77         0                 0
# 67070          DEM         1            22         0                 0
# 67071          DEM         1             0       111                 0
# 67072          DEM         1             0         0                 0
# 67073          DEM         1            78         0                 0
# 67074          DEM         1             0         0                13
# 67075          DEM         1            55         0                 0
# 67076          DEM         1            80         0                 0
# 67077          DEM         1            14         0                 0
# 67078          DEM         1            11         0                 0
# 67079          DEM         1            23         0                 0
# 67080          DEM         1            22         0                 0
# 67081          DEM         1            28         0                 0
# 67082          DEM         1            42         0                 0
# 67083          DEM         1            15         0                 0
# 67084          DEM         1            12         0                 0
# 67085          DEM         1             0         0                 7
# 67086          DEM         1             0        41                 0
# 67087          DEM         1            49         0                 0
#
#        Provisional  Total Votes      PrecReturns_id
# 0                0          125         ALEXANDER|E
# 1                0          122      ALEXANDER|S1S2
# 2                0           70      ALEXANDER|LRSL
# 3                0           74         ALEXANDER|W
# 4                0          122      ALEXANDER|T2T3
# 5                0          157        ALEXANDER|B2
# 6                1          102      ALEXANDER|G1G2
# 7                0          118        ALEXANDER|B1
# 8                1          177    ALEXANDER|T1T4T5
# 9                0           59         ALEXANDER|M
# 10               0           75        ALEXANDER|B1
# 11               0          106         ALEXANDER|E
# 12               0          193    ALEXANDER|T1T4T5
# 13               1          143      ALEXANDER|S1S2
# 14               0           62         ALEXANDER|W
# 15               0           71      ALEXANDER|LRSL
# 16               1          140        ALEXANDER|B2
# 17               0           87         ALEXANDER|M
# 18               0          192      ALEXANDER|T2T3
# 19               0           82      ALEXANDER|G1G2
# 20               0            2        ALEXANDER|B1
# 21               0            5      ALEXANDER|LRSL
# 22               0           13        ALEXANDER|B2
# 23               0            4         ALEXANDER|M
# 24               0            8      ALEXANDER|S1S2
# 25               0            3         ALEXANDER|W
# 26               0            4      ALEXANDER|G1G2
# 27               0            6      ALEXANDER|T2T3
# 28               0            7         ALEXANDER|E
# 29               0            7    ALEXANDER|T1T4T5
# ...            ...          ...                 ...
# 67058            0           83         YADKIN|NLIB
# 67059            2            2  YADKIN|PROVISIONAL
# 67060            0           22         YADKIN|NFAL
# 67061            0           64         YADKIN|FBSH
# 67062            0           58         YADKIN|FBSH
# 67063            0           34         YADKIN|SFAL
# 67064            0           32         YADKIN|NBCK
# 67065            0          109         YADKIN|NKNB
# 67066            0           33         YADKIN|SBCK
# 67067            0           11         YADKIN|SKNB
# 67068            0           45         YADKIN|DCRK
# 67069            0           77         YADKIN|EBND
# 67070            0           22         YADKIN|NFAL
# 67071            0          111     YADKIN|ONE STOP
# 67072            3            3  YADKIN|PROVISIONAL
# 67073            0           78         YADKIN|NLIB
# 67074            0           13     YADKIN|ABSENTEE
# 67075            0           55         YADKIN|SLIB
# 67076            0           80         YADKIN|BNVL
# 67077            0           14         YADKIN|NBCK
# 67078            0           11         YADKIN|SBCK
# 67079            0           23         YADKIN|FBSH
# 67080            0           22         YADKIN|SLIB
# 67081            0           28         YADKIN|NKNB
# 67082            0           42         YADKIN|EBND
# 67083            0           15         YADKIN|SFAL
# 67084            0           12         YADKIN|NFAL
# 67085            0            7     YADKIN|ABSENTEE
# 67086            0           41     YADKIN|ONE STOP
# 67087            0           49         YADKIN|NLIB
#
# [67088 rows x 15 columns]

# %%
# Create a crosswalk DataFrame named 'xwalk'.
# PrecReturns: Unique precinct id. To be merged on 'Prec_Uid'
# Match: 'PERFECT_MATCH', 'GEOM_MATCH', 'COUNTY_WIDE'
# Details: further details on each kind of match
xwalk = pd.DataFrame(returns['PrecReturns_id'].unique(), columns=['PrecReturns_id'])

# %%
# Perfect matches
xwalk['Match'] = np.where(xwalk['PrecReturns_id'].isin(perfect), 'PERFECT_MATCH', 'UNKNOWN')
xwalk['Details'] = np.where(xwalk['PrecReturns_id'].isin(perfect), xwalk['PrecReturns_id'],'UNKNOWN')

# %%
# Geometry perfectly matches
xwalk['Match'][(xwalk['Match']=='UNKNOWN') & (xwalk['PrecReturns_id'].isin(geom))] = 'GEOM_MATCH'
xwalk['Details'][xwalk['Match']=='GEOM_MATCH'] = xwalk['PrecReturns_id']

# %%
xwalk['Match'][xwalk['PrecReturns_id'].isin(merged.keys())] = 'MERGED'
xwalk['Details'][xwalk['Match']=='MERGED'] = xwalk['PrecReturns_id'][xwalk['Match']=='MERGED'].apply(lambda i: merged[i])

# %%
xwalk['Match'][xwalk['PrecReturns_id'].isin(split.keys())] = 'SPLIT'
xwalk['Details'][xwalk['Match']=='SPLIT'] = xwalk['PrecReturns_id'][xwalk['Match']=='SPLIT'].apply(lambda i: split[i])

# %%
set([i.split('|')[1] for i in xwalk['PrecReturns_id'][xwalk['Match']=='UNKNOWN']])
# Out:
# {'02',
#  '03',
#  '05',
#  '06',
#  '07',
#  '20-15',
#  '20-16',
#  '20-17',
#  'ABS/CURB/PROV 1',
#  'ABSEN',
#  'ABSENTEE',
#  'ABSENTEE #1',
#  'ABSENTEE #2',
#  'ABSENTEE ADDTNL',
#  'ABSENTEE BY MAIL',
#  'ABSENTEE BY MAIL DEM',
#  'ABSENTEE MAIL',
#  'CURBSIDE',
#  'CURBSIDE DEM',
#  'EUR',
#  'FP02',
#  'FP05',
#  'H09',
#  'ONE STOP',
#  'ONE STOP #1',
#  'ONE STOP #2',
#  'ONE STOP #3',
#  'ONE STOP #4',
#  'ONE STOP A 100',
#  'ONE STOP B 100',
#  'ONE STOP C 100',
#  'ONE STOP D 100',
#  'ONE STOP E 100',
#  'ONE STOP PAPER',
#  'OS ADMIN',
#  'OS AG CENTER',
#  'OS AHOSKIE',
#  'OS ASU-PLEMMONS SU',
#  'OS AUR',
#  'OS AYDEN',
#  'OS B-BORO',
#  'OS BEL',
#  'OS BLOWING ROCK',
#  'OS BOE',
#  'OS BOE 200',
#  'OS CAB PAPER',
#  'OS CFCC PAPER',
#  'OS CHOCO',
#  'OS CO 200',
#  'OS COLE PAPER',
#  'OS COMMISSIONERS BOARD RM',
#  'OS COMMUNITY SCH',
#  'OS COOP PAPER',
#  'OS COTC',
#  'OS COUNTY BLDG',
#  'OS CTH',
#  'OS DANBURY',
#  'OS DEEP GAP',
#  'OS DUBLIN',
#  'OS EA',
#  'OS ELLERBE PAPER',
#  'OS ER',
#  'OS FAIR #1',
#  'OS FAIR #2',
#  'OS FARMVILLE',
#  'OS GASTON',
#  'OS GRANITE FALLS',
#  'OS GVT PAPER',
#  'OS HALIFAX',
#  'OS HD 200',
#  'OS HOS',
#  'OS KING',
#  'OS LENOIR',
#  'OS LIBRARY',
#  'OS LITTLETON',
#  'OS LOB',
#  'OS LOB #1',
#  'OS LOB #2',
#  'OS MBORO',
#  'OS MEAT CAMP',
#  'OS MILLER CRK',
#  'OS MTN VIEW',
#  'OS MULBERRY',
#  'OS MX #1',
#  'OS MX #2',
#  'OS NASHVILLE',
#  'OS NCC',
#  'OS NHC',
#  'OS NLB PAPER',
#  'OS OCK',
#  'OS OFFICE',
#  'OS OLD FORT LIBRARY',
#  'OS PEM #1',
#  'OS PEM #2',
#  'OS PLEASANT HILL',
#  'OS POW',
#  'OS RICH SQUARE',
#  'OS RINGWOOD',
#  'OS ROANOKE RAPIDS',
#  'OS ROCKY MOUNT',
#  'OS SC',
#  'OS SCOTLAND NECK',
#  'OS SPRING HOPE',
#  'OS SRC PAPER',
#  'OS WC',
#  'OS WESTERN WCC',
#  'OS WILLIS BLDG',
#  'OS WINERVILLE FIRE',
#  'OS-AG M100',
#  'OS-ANDERSON',
#  'OS-ANGIER',
#  'OS-BOE',
#  'OS-BOLTON',
#  'OS-CEN',
#  'OS-CHADBOURN',
#  'OS-DALLAS',
#  'OS-DTCC',
#  'OS-DUKE',
#  'OS-EAS',
#  'OS-EAST',
#  'OS-EASTCOLUMBUS',
#  'OS-EMM',
#  'OS-ERL',
#  'OS-ERUF',
#  'OS-ERWIN',
#  'OS-FAIRBLUFF',
#  'OS-FS83',
#  'OS-LIB',
#  'OS-LINCOLN',
#  'OS-LOBBY',
#  'OS-LOC',
#  'OS-MHD',
#  'OS-MOUNT HOLLY',
#  'OS-NCCU',
#  'OS-NL',
#  'OS-NOR',
#  'OS-NRL',
#  'OS-PINETOPS',
#  'OS-ROCKYMOUNT',
#  'OS-ROSE',
#  'OS-SRL',
#  'OS-TABORCITY',
#  'OS-TARBORO',
#  'OS-WE M100',
#  'OS-WES',
#  'OS-WEST',
#  'OS-WESTERN',
#  'OSAP',
#  'OSAV',
#  'OSCA',
#  'OSCH',
#  'OSFV',
#  'OSLL',
#  'OSLOB',
#  'OSNR',
#  'OSWD',
#  'PR34',
#  'PR35',
#  'PROVI',
#  'PROVISIONAL',
#  'PROVISIONAL #1',
#  'PROVISIONAL #2',
#  'PROVISIONAL DEM',
#  'RR 6',
#  'RR 8',
#  'TRANSFER',
#  'TRANSFER 100',
#  'WEL 1',
#  'WEL 2'}

# %%
re_substr = '(\|ABS)|(\|CURB)|(\|ONE)|(\|OS)|(\|PROVI)|(\|TRANSFER)'

# %%
# Labeling matches on county level unsorted ballots as 'County_Level'. Details: Precinct ID.
xwalk['Match'][xwalk['Match']=='UNKNOWN'] = np.where(xwalk['PrecReturns_id'][xwalk['Match']=='UNKNOWN'].str.contains(re_substr), 'COUNTY_LEVEL', 'UNKNOWN')
# Out:
# /Users/ericma/anaconda3/envs/learn-env/lib/python3.6/site-packages/ipykernel_launcher.py:2: UserWarning: This pattern has match groups. To actually get the groups, use str.extract.

# %%
xwalk['Details'][xwalk['Match']=='COUNTY_LEVEL'] = xwalk[xwalk['Match']=='COUNTY_LEVEL'].apply(lambda i: i['PrecReturns_id'].split('|')[1], axis=1)

# %%
oldgeom = precincts2014['Prec_Uid'].tolist()
newgeom = precincts2016['Prec_Uid'].tolist()

# %%
# Check if precinct id matches old 2014 id (10)
xwalk['Match'][(xwalk['Match']=='UNKNOWN') & (xwalk['PrecReturns_id'].isin(oldgeom))] = 'GEOM_OTHER'
xwalk['Details'][xwalk['Match']=='GEOM_OTHER'] = '2014 ' + xwalk['PrecReturns_id']

# %%
# Unknown changes (5)
xwalk['Match'][(xwalk['Match']=='UNKNOWN') & (xwalk['PrecReturns_id'].isin(newgeom))] = 'GEOM_OTHER'

# %%
# No matches found (3)
xwalk[(xwalk['Match']=='UNKNOWN')]
# Out:
#         PrecReturns_id    Match  Details
# 1942   NEW HANOVER|H09  UNKNOWN  UNKNOWN
# 1947  NEW HANOVER|FP05  UNKNOWN  UNKNOWN
# 1963  NEW HANOVER|FP02  UNKNOWN  UNKNOWN

# %%
xwalk.to_csv('NC_Crosswalk.csv')
